# %%
! pip install -r /Users/yash/Developer/prjct_mod/project_comb/privacy_detection/requirements.txt


print("Environment setup complete. You can now run the application.")
# Out:
# ...
#      ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/400.7 MB 2.0 MB/s eta 0:02:06^C
# Environment setup complete. You can now run the application.
